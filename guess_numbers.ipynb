# %% [markdown]
# Напишите несколько вариантов программы, в которой пользователю предлагается отгадать число (или числа).

# %% [markdown]
# **Вариант 1**
# Компьютер генерирует целое число в диапазоне от 1 до 10 (включительно) и предлагает пользователю отгадать его. Предоставляется одна попытка, выводится результат.
#
# _Пример 1_
# > Я загадал число от 1 до 10!
# > Отгадай его: **6**
# > Не угадал!
#
# _Пример 2_
# > Я загадал число от 1 до 10!
# > Отгадай его: **7**
# > Угадал!

# %%
# Вариант 1
from random import randint

print("Я загадал число от 1 до 10!")
number = randint(1,10)
us_num = int(input("Угадай моё число:"))
if us_num == number:
    print("Угадал!")
else:
    print("Не угадал!")
# Out:
# Я загадал число от 1 до 10!
# Не угадал!

# %% [markdown]
# **Вариант 2**
# Компьютер генерирует целое число в диапазоне от 1 до 10 (включительно) и предлагает пользователю отгадать его. Предоставляется одна попытка, выводится результат.
# _Если число не угадано, отображается дополнительная информация (см. примеры)_
#
# _Пример 1_
# > Я загадал число от 1 до 10!
# > Отгадай его: **2**
# > Не угадал!
# > Моё число больше!
#
# _Пример 2_
# > Я загадал число от 1 до 10!
# > Отгадай его: **9**
# > Не угадал!
# > Моё число меньше!
#
# _Пример 3_
# > Я загадал число от 1 до 10!
# > Отгадай его: **7**
# > Угадал!

# %%
# Вариант 2
from random import randint

print("Я загадал число от 1 до 10!")

number = randint(1,10)

us_num = int(input("Угадай моё число:"))

if us_num == number:
    print("Угадал!")
elif us_num < number:
    print("не угадал Моё число больше!")
else:
    print("не угадал Моё число меньше!")

# %% [markdown]
# **Вариант 3**
# Компьютер генерирует целое число в диапазоне от 1 до 10 (включительно) и предлагает пользователю отгадать его. Предоставляется **неограниченное число попыток**. Программа завершается, когда пользователь угадывает число.
#
# _Пример_
# > Я загадал число от 1 до 10!
# > Отгадай число: **2**
# > Не угадал! Моё число больше!
# > Отгадай число: **8**
# > Не угадал! Моё число меньше!
# > Отгадай число: **3**
# > Не угадал! Моё число больше!
# > Отгадай число: **7**
# > Угадал!

# %%
# Вариант 3
rom random import randint

print("Я загадал число от 1 до 10!")

number = randint(1,10)

us_num = int(input("Угадай моё число:"))

while us_num != number:
    if us_num == number:
        print("Угадал!")
        us_num = int(input(" Попробуй еще раз:"))
    elif us_num < number:
        print("не угадал Моё число больше!")
        us_num = int(input(" Попробуй еще раз:"))
    else:
        print("не угадал Моё число меньше!")
        us_num = int(input(" Попробуй еще раз:"))

print('Ты угадал')

# %% [markdown]
# **Вариант 4**
# Компьютер генерирует целое число в диапазоне от 1 до 10 (включительно) и предлагает пользователю отгадать его. Предоставляется **неограниченное число попыток**. При этом количество попыток и номер текущей попытки фиксируется. Программа завершается, когда пользователь угадывает число. Отображается информация о том, сколько попыток понадобилось (см. пример)
#
# _Пример_
# > Я загадал число от 1 до 10!
# > Отгадай число (попытка № 1): **2**
# > Не угадал! Моё число больше!
# > Отгадай число (попытка № 2): **8**
# > Не угадал! Моё число меньше!
# > Отгадай число (попытка № 3): **3**
# > Не угадал! Моё число больше!
# > Отгадай число (попытка № 4): **7**
# > Угадал!
# > Понадобилось попыток: 4

# %%
# Вариант 4
from random import randint

print("Я загадал число от 1 до 10!")

number = randint(1,10)

us_num = int(input("Угадай моё число:"))

try_num = 0

while us_num != number:
    if us_num < number:
        print("не угадал Моё число больше!")
        trey_num += 1
        print("Попытка №", ball)
        us_num = int(input(" Попробуй еще раз:"))
    else:
        print("не угадал Моё число меньше!")
        try_num += 1
        print("Попытка №", ball)
        us_num = int(input(" Попробуй еще раз:"))

print("Ты угадал!")

print('Понадобилось попыток', try_num)

# %% [markdown]
# **Вариант 5**
# Компьютер генерирует целое число в диапазоне от 1 до 10 (включительно) и предлагает пользователю отгадать его. Предоставляется **3 попытки**. При вводе отображается оставшееся количество попыток. Программа завершается, когда пользователь угадывает число или 3 раза называет неверное значение.
#
# _Пример 1_
# > Я загадал число от 1 до 10. Отгадай его!
# > У тебя попыток: 3
# > Какое число я загадал: **2**
# > Не угадал! Моё число больше!
# > У тебя попыток: 2
# > Какое число я загадал: **8**
# > Не угадал! Моё число меньше!
# > У тебя попыток: 1
# > Какое число я загадал: **7**
# > Угадал!
# > Понадобилось попыток: 3
#
# _Пример 2_
# > Я загадал число от 1 до 10. Отгадай его!
# > У тебя попыток: 3
# > Какое число я загадал: **2**
# > Не угадал! Моё число больше!
# > У тебя попыток: 2
# > Какое число я загадал: **8**
# > Не угадал! Моё число меньше!
# > У тебя попыток: 1
# > Какое число я загадал: **3**
# > Не угадал! Моё число больше!
# > Game Over (проиграно), попытки закончились

# %%
# Вариант 5
from random import randint
def try_word(num):
    '''return correct form of the russian word попытка 
    by a given number
    example:
    1 -> попытка
    2 -> попытки
    etc.
    '''
    if num == 1:
        return "попытка"
    if 2 <= num <= 4:
        return "попытки"
    else:
        return "попыток"


def get_number(min_num, max_num):
    '''takes users input untill the correct value entered
    (in the given range)'''
    while True:
        number = int(input(f"Введите число от {min_num} до {max_num}: "))
        if number in range(min_num, max_num+1):
            return number
        print("Введено некорректное значение! Попробуйте еще раз...")


from random import randint
from utils import *

number = randint(1, 10)

count = 1
print("Укажите число попыток...")
TRIES = get_number(1, 10)

print(number)

print(f"Угадай моё число за {TRIES} {try_word(TRIES)}!")

while True:
    answer = int(input("Отгадай: "))
    
    # Выходим из цикла, если угадал
    if answer == number:
        print("Угадал!")
        print("Понадобилось попыток:", count)
        break

    # Если не угадал, выполняем соотв. строки
    print("Не угадал!")
    
    if number > answer:
        print("Моё число больше")
    else:
        print("Моё число меньше")
        
    if count >= TRIES:
        print('Попытки закончились, ты проиграл')
        break

    count += 1


# добавьте необходимый код программы здесь
